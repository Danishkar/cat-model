# %%
import pickle
import time
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow import keras
from keras import layers
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.optimizers import Adam

import numpy as np
import cv2
import os
import random
import matplotlib.pyplot as plt
import pickle

DIRECTORY = r'D:\Desktop\Cat_model\dataset\train'
CATEGORIES = ["Earmites","Ringworm"]

IMG_SIZE = 130

data = []

for category in CATEGORIES:
    folder = os.path.join(DIRECTORY, category)
    label = CATEGORIES.index(category)
    for img in os.listdir(folder):
        img_path = os.path.join(folder, img)
        img_arr = cv2.imread(img_path)
        img_arr = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE))
        data.append([img_arr, label])
random.shuffle(data)


X=[]
y=[]

for features, labels in data:
    X.append(features)
    y.append(labels)


X = np.array(X)
y = np.array(y)

# y = to_categorical(y)

model = Sequential()

# Add a convolutional layer with 32 filters, a 3x3 kernel, and ReLU activation
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(130, 130, 3)))

# Add a max pooling layer with a 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Add a flatten layer to convert the 2D feature maps to a 1D feature vector
model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

# Add a dense layer with 128 neurons and ReLU activation
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
# Add an output layer with 2 neurons and a softmax activation
model.add(Dense(1, activation='sigmoid'))

# Compile the model with binary cross-entropy loss and the Adam optimizer
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

base_dir = 'dataset'

train_datagen = image_dataset_from_directory(base_dir+"/train",
                                                  image_size=(130,130),
                                                  subset='training',
                                                  seed = 1,
                                                 validation_split=0.1,
                                                  batch_size= 10)
test_datagen = image_dataset_from_directory(base_dir+"/test",
                                                  image_size=(130,130),
                                                  subset='validation',
                                                  seed = 1,
                                                 validation_split=0.1,
                                                  batch_size= 10)

model.fit(train_datagen,epochs=25,validation_data=test_datagen,validation_steps=35/32)
model.save('cat.model(2)')
# Out:
# Found 468 files belonging to 2 classes.
# Using 422 files for training.
# Found 112 files belonging to 2 classes.
# Using 11 files for validation.
# Epoch 1/25
# 43/43 [==============================] - 14s 245ms/step - loss: 6.6301 - accuracy: 0.6185 - val_loss: 0.7003 - val_accuracy: 0.4545
# Epoch 2/25
# 43/43 [==============================] - 10s 233ms/step - loss: 0.4820 - accuracy: 0.7488 - val_loss: 0.6753 - val_accuracy: 0.8182
# Epoch 3/25
# 43/43 [==============================] - 10s 236ms/step - loss: 0.3806 - accuracy: 0.8152 - val_loss: 0.6956 - val_accuracy: 0.6364
# Epoch 4/25
# 43/43 [==============================] - 10s 240ms/step - loss: 0.3232 - accuracy: 0.8199 - val_loss: 0.6772 - val_accuracy: 0.4545
# Epoch 5/25
# 43/43 [==============================] - 11s 243ms/step - loss: 0.2834 - accuracy: 0.8649 - val_loss: 1.4308 - val_accuracy: 0.2727
# Epoch 6/25
# 43/43 [==============================] - 10s 240ms/step - loss: 0.2526 - accuracy: 0.8957 - val_loss: 0.7295 - val_accuracy: 0.6364
# Epoch 7/25
# 43/43 [==============================] - 10s 239ms/step - loss: 0.1834 - accuracy: 0.9171 - val_loss: 0.7480 - val_accuracy: 0.3636
# Epoch 8/25
# 43/43 [==============================] - 10s 238ms/step - loss: 0.3226 - accuracy: 0.8720 - val_loss: 0.7100 - val_accuracy: 0.3636
# Epoch 9/25
# 43/43 [==============================] - 11s 249ms/step - loss: 0.5737 - accuracy: 0.8791 - val_loss: 0.7264 - val_accuracy: 0.3636
# Epoch 10/25
# 43/43 [==============================] - 11s 248ms/step - loss: 0.2538 - accuracy: 0.8744 - val_loss: 0.7659 - val_accuracy: 0.2727
# Epoch 11/25
# 43/43 [==============================] - 11s 247ms/step - loss: 0.2046 - accuracy: 0.9242 - val_loss: 0.8448 - val_accuracy: 0.4545
# Epoch 12/25
# 43/43 [==============================] - 10s 241ms/step - loss: 0.1920 - accuracy: 0.9123 - val_loss: 0.7297 - val_accuracy: 0.3636
# Epoch 13/25
# 43/43 [==============================] - 10s 234ms/step - loss: 0.1775 - accuracy: 0.9265 - val_loss: 0.7357 - val_accuracy: 0.3636
# Epoch 14/25
# 43/43 [==============================] - 10s 237ms/step - loss: 0.1602 - accuracy: 0.9431 - val_loss: 0.7422 - val_accuracy: 0.3636
# Epoch 15/25
# 43/43 [==============================] - 11s 260ms/step - loss: 0.2363 - accuracy: 0.9100 - val_loss: 0.9378 - val_accuracy: 0.2727
# Epoch 16/25
# 43/43 [==============================] - 11s 250ms/step - loss: 0.1680 - accuracy: 0.9218 - val_loss: 0.9031 - val_accuracy: 0.2727
# Epoch 17/25
# 43/43 [==============================] - 11s 253ms/step - loss: 0.1199 - accuracy: 0.9479 - val_loss: 0.9199 - val_accuracy: 0.2727
# Epoch 18/25
# 43/43 [==============================] - 11s 252ms/step - loss: 0.5109 - accuracy: 0.9147 - val_loss: 1.1516 - val_accuracy: 0.1818
# Epoch 19/25
# 43/43 [==============================] - 11s 258ms/step - loss: 0.7729 - accuracy: 0.8555 - val_loss: 0.7705 - val_accuracy: 0.3636
# Epoch 20/25
# 43/43 [==============================] - 11s 255ms/step - loss: 0.2774 - accuracy: 0.8555 - val_loss: 0.7599 - val_accuracy: 0.3636
# Epoch 21/25
# 43/43 [==============================] - 11s 256ms/step - loss: 0.1683 - accuracy: 0.9242 - val_loss: 0.7340 - val_accuracy: 0.3636
# Epoch 22/25
# 43/43 [==============================] - 11s 256ms/step - loss: 0.1907 - accuracy: 0.9289 - val_loss: 0.8736 - val_accuracy: 0.1818
# Epoch 23/25
# 43/43 [==============================] - 11s 257ms/step - loss: 0.1967 - accuracy: 0.9194 - val_loss: 0.6721 - val_accuracy: 0.4545
# Epoch 24/25
# 43/43 [==============================] - 11s 258ms/step - loss: 0.2509 - accuracy: 0.9028 - val_loss: 0.8244 - val_accuracy: 0.2727
# Epoch 25/25
# 43/43 [==============================] - 11s 259ms/step - loss: 0.1329 - accuracy: 0.9384 - val_loss: 0.5972 - val_accuracy: 0.5455
# INFO:tensorflow:Assets written to: cat.model(2)\assets

# %%
from keras.models import load_model
import cv2
import numpy as np

# Load the saved model
model = load_model('cat.model')

# Load the image you want to classify
img = cv2.imread('D:\\Downloads\\download3.jfif')
img = cv2.resize(img, (130, 130))
img = np.reshape(img, [1, 130, 130, 3])

prediction = model.predict(img)

print(prediction)
if (prediction >= 0.5):
    print("Ringworm")
    print("probability "+ str(prediction[0][0]))
else:
    print("Earmites")
    print("probability "+ str(1 - prediction[0][0]))
# Out:
# [[0.99354076]]
# Ringworm
# probability 0.99354076

# %%
new_image = load_img('D:\\Downloads\\download4.jfif', target_size=(130, 130))

# Preprocess the image
new_image = np.array(new_image)
new_image = new_image.astype('float32') / 255.0
new_image = np.expand_dims(new_image, axis=0)

# Make a prediction
prediction = model.predict(new_image)

# Print the predicted probabilities
print(prediction)
if (prediction >= 0.5):
    print("Ringworm")
    print("probability "+ str(prediction[0][0]))
else:
    print("Earmites")
    print("probability "+ str(1 - prediction[0][0]))
# print(CATEGORIES[prediction.argmax()])
# print(CATEGORIES[1])
